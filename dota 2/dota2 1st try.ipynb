# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
feature = pd.read_csv('D:/Prog/ML/datasets/data/features.csv')

# %%
feature.head()
# Out:
#    match_id  start_time  lobby_type  r1_hero  r1_level  r1_xp  r1_gold  r1_lh  \
# 0         0  1430198770           7       11         5   2098     1489     20
# 1         1  1430220345           0       42         4   1188     1033      9
# 2         2  1430227081           7       33         4   1319     1270     22
# 3         3  1430263531           1       29         4   1779     1056     14
# 4         4  1430282290           7       13         4   1431     1090      8
#
#    r1_kills  r1_deaths  ...  dire_boots_count  dire_ward_observer_count  \
# 0         0          0  ...                 4                         2
# 1         0          1  ...                 4                         3
# 2         0          0  ...                 4                         3
# 3         0          0  ...                 4                         2
# 4         1          0  ...                 3                         3
#
# ...

# %%
feature.info(max_cols=130)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97230 entries, 0 to 97229
# Data columns (total 109 columns):
# match_id                       97230 non-null int64
# start_time                     97230 non-null int64
# lobby_type                     97230 non-null int64
# r1_hero                        97230 non-null int64
# r1_level                       97230 non-null int64
# r1_xp                          97230 non-null int64
# r1_gold                        97230 non-null int64
# r1_lh                          97230 non-null int64
# r1_kills                       97230 non-null int64
# r1_deaths                      97230 non-null int64
# r1_items                       97230 non-null int64
# r2_hero                        97230 non-null int64
# r2_level                       97230 non-null int64
# r2_xp                          97230 non-null int64
# r2_gold                        97230 non-null int64
# r2_lh                          97230 non-null int64
# ...

# %%
feature.iloc[:,:20].head()
# Out:
#    match_id  start_time  lobby_type  r1_hero  r1_level  r1_xp  r1_gold  r1_lh  \
# 0         0  1430198770           7       11         5   2098     1489     20
# 1         1  1430220345           0       42         4   1188     1033      9
# 2         2  1430227081           7       33         4   1319     1270     22
# 3         3  1430263531           1       29         4   1779     1056     14
# 4         4  1430282290           7       13         4   1431     1090      8
#
#    r1_kills  r1_deaths  r1_items  r2_hero  r2_level  r2_xp  r2_gold  r2_lh  \
# 0         0          0         7       67         3    842      991     10
# 1         0          1        12       49         4   1596      993     10
# 2         0          0        12       98         3   1314      775      6
# 3         0          0         5       30         2    539      539      1
# 4         1          0         8       27         2    629      552      0
#
#    r2_kills  r2_deaths  r2_items  r3_hero
# ...

# %%
feature.iloc[:,20:40].head()
# Out:
#    r3_level  r3_xp  r3_gold  r3_lh  r3_kills  r3_deaths  r3_items  r4_hero  \
# 0         5   1909     1143     10         0          0         8       20
# 1         4   1506     1502     18         1          0         7       37
# 2         3   1297      909      0         1          0         6       27
# 3         5   2037     1139     15         0          0         6       37
# 4         3    884      927      0         1          0         8       72
#
#    r4_level  r4_xp  r4_gold  r4_lh  r4_kills  r4_deaths  r4_items  r5_hero  \
# 0         3    757      741      6         0          0         7      105
# 1         3    669      631      7         0          0         7       26
# 2         5   2360     2096     26         1          1         6        4
# 3         2    591      499      0         0          0         6       41
# 4         3    925     1439     16         1          0        11       93
#
#    r5_level  r5_xp  r5_gold  r5_lh
# ...

# %%
feature.iloc[:,40:60].head()
# Out:
#    r5_kills  r5_deaths  r5_items  d1_hero  d1_level  d1_xp  d1_gold  d1_lh  \
# 0         0          1        11        4         3   1058      996     12
# 1         0          0         5       39         5   1960     1384     16
# 2         0          0         9       22         5   2305     2028     19
# 3         0          0         6       96         5   1878     1174     17
# 4         0          0         8       26         3    704      586      1
#
#    d1_kills  d1_deaths  d1_items  d2_hero  d2_level  d2_xp  d2_gold  d2_lh  \
# 0         0          0         6       42         4   1085      986     12
# 1         0          0         8       88         3    640      566      1
# 2         1          1        10       66         3   1024      959     19
# 3         0          0         6       48         3    732     1468     22
# 4         0          2         9       69         3   1169     1665     20
#
#    d2_kills  d2_deaths  d2_items  d3_hero
# ...

# %%
feature.iloc[:,60:80].head()
# Out:
#    d3_level  d3_xp  d3_gold  d3_lh  d3_kills  d3_deaths  d3_items  d4_hero  \
# 0         5   2052     1536     23         0          0         6       37
# 1         3    720     1350      2         2          0        12        7
# 2         3    755      620      3         0          0         8       29
# 3         4   1681     1051     11         0          0         7      102
# 4         3   1055      638      1         0          0         9       25
#
#    d4_level  d4_xp  d4_gold  d4_lh  d4_kills  d4_deaths  d4_items  d5_hero  \
# 0         3    742      500      2         0          0         8       84
# 1         2    440      583      0         0          0         7       12
# 2         4   1319      667      4         0          0         7       80
# 3         2    674      537      1         0          0         7       20
# 4         5   1815     1275     18         0          0         8        8
#
#    d5_level  d5_xp  d5_gold  d5_lh
# ...

# %%
feature.iloc[:,80:100].head()
# Out:
#    d5_kills  d5_deaths  d5_items  first_blood_time  first_blood_team  \
# 0         1          0         9               7.0               1.0
# 1         0          0         9              54.0               1.0
# 2         0          0         7             224.0               0.0
# 3         0          0         7               NaN               NaN
# 4         0          1         7             -21.0               1.0
#
#    first_blood_player1  first_blood_player2  radiant_bottle_time  \
# 0                  9.0                  NaN                134.0
# 1                  7.0                  NaN                173.0
# 2                  3.0                  NaN                 63.0
# 3                  NaN                  NaN                208.0
# 4                  6.0                  NaN                166.0
#
#    radiant_courier_time  radiant_flying_courier_time  radiant_tpscroll_count  \
# 0                 -80.0                        244.0                       2
# ...

# %%
feature.iloc[:,100:120].head()
# Out:
#    dire_ward_observer_count  dire_ward_sentry_count  dire_first_ward_time  \
# 0                         2                       2                 -52.0
# 1                         3                       1                  -5.0
# 2                         3                       1                  13.0
# 3                         2                       0                  27.0
# 4                         3                       0                 -16.0
#
#    duration  radiant_win  tower_status_radiant  tower_status_dire  \
# 0      2874            1                  1796                  0
# 1      2463            1                  1974                  0
# 2      2130            0                     0               1830
# 3      1459            0                  1920               2047
# 4      2449            0                     4               1974
#
#    barracks_status_radiant  barracks_status_dire
# 0                       51                     0
# ...

# %%
feature.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Columns: 109 entries, match_id to barracks_status_dire
# dtypes: float64(12), int64(97)
# memory usage: 24.9 MB

# %%
feature.iloc[:,:20].describe()
# Out:
#            match_id    start_time    lobby_type       r1_hero      r1_level  \
# count  30000.000000  3.000000e+04  30000.000000  30000.000000  30000.000000
# mean   17658.721067  1.437005e+09      3.045700     50.271067      3.411033
# std    10165.299387  3.583042e+06      3.048889     32.825337      1.148504
# min        0.000000  1.430199e+09      0.000000      1.000000      0.000000
# 25%     8854.750000  1.433836e+09      1.000000     21.000000      3.000000
# 50%    17691.500000  1.437087e+09      1.000000     49.000000      3.000000
# 75%    26452.250000  1.440166e+09      7.000000     77.000000      4.000000
# max    35286.000000  1.442724e+09      7.000000    112.000000      6.000000
#
#               r1_xp       r1_gold         r1_lh      r1_kills     r1_deaths  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean    1223.451767   1125.159300     11.196167      0.329567      0.341933
# ...

# %%
feature.iloc[:,20:40].describe()
# Out:
#            r3_level         r3_xp       r3_gold         r3_lh      r3_kills  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean       3.331167   1178.650867   1077.941067     10.307033      0.311667
# std        1.135813    574.251434    452.164277      9.188992      0.631198
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        3.000000    704.000000    676.000000      2.000000      0.000000
# 50%        3.000000   1083.000000   1001.000000      8.000000      0.000000
# 75%        4.000000   1654.250000   1415.000000     18.000000      0.000000
# max        7.000000   3112.000000   3454.000000     51.000000      8.000000
#
#           r3_deaths      r3_items       r4_hero      r4_level         r4_xp  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean       0.333667      7.956400     51.107667      3.272100   1148.095833
# ...

# %%
feature.iloc[:,40:60].describe()
# Out:
#            r5_kills     r5_deaths      r5_items       d1_hero      d1_level  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean       0.306467      0.334667      7.998533     50.709033      3.430600
# std        0.621255      0.610364      2.409037     32.643163      1.142961
# min        0.000000      0.000000      0.000000      1.000000      0.000000
# 25%        0.000000      0.000000      6.000000     22.000000      3.000000
# 50%        0.000000      0.000000      8.000000     49.000000      3.000000
# 75%        0.000000      1.000000      9.000000     79.000000      4.000000
# max        6.000000      5.000000     22.000000    112.000000      7.000000
#
#               d1_xp     d1_gold         d1_lh      d1_kills     d1_deaths  \
# count  30000.000000  30000.0000  30000.000000  30000.000000  30000.000000
# mean    1229.734433   1131.8333     11.257467      0.348867      0.319533
# ...

# %%
feature.iloc[:,60:80].describe()
# Out:
#            d3_level         d3_xp       d3_gold         d3_lh      d3_kills  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean       3.348433   1187.500267   1081.239733     10.301633      0.329800
# std        1.128688    568.186405    447.369557      9.162892      0.648264
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        3.000000    722.000000    686.000000      2.000000      0.000000
# 50%        3.000000   1098.000000   1012.000000      8.000000      0.000000
# 75%        4.000000   1662.000000   1413.000000     18.000000      1.000000
# max        6.000000   3075.000000   3336.000000     46.000000      8.000000
#
#           d3_deaths      d3_items       d4_hero      d4_level         d4_xp  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean       0.321833      8.000400     51.493933      3.308000   1165.381133
# ...

# %%
feature.iloc[:,80:100].describe()
# Out:
#            d5_kills     d5_deaths      d5_items  first_blood_time  \
# count  30000.000000  30000.000000  30000.000000      24434.000000
# mean       0.337000      0.317400      8.024400         93.684129
# std        0.654761      0.591159      2.437308         87.021234
# min        0.000000      0.000000      0.000000        -53.000000
# 25%        0.000000      0.000000      6.000000          8.000000
# 50%        0.000000      0.000000      8.000000         85.000000
# 75%        1.000000      1.000000     10.000000        156.000000
# max        8.000000      5.000000     23.000000        300.000000
#
#        first_blood_team  first_blood_player1  first_blood_player2  \
# count      24434.000000         24434.000000                  0.0
# mean           0.522264             4.586723                  NaN
# std            0.499514             2.898879                  NaN
# min            0.000000             0.000000                  NaN
# ...

# %%
feature.iloc[:,100:120].describe()
# Out:
#        dire_ward_observer_count  dire_ward_sentry_count  dire_first_ward_time  \
# count              30000.000000            30000.000000          29365.000000
# mean                   2.407700                0.617333             -5.742993
# std                    0.813328                0.695688             42.859902
# min                    0.000000                0.000000            -84.000000
# 25%                    2.000000                0.000000            -31.000000
# 50%                    2.000000                1.000000            -16.000000
# 75%                    3.000000                1.000000              8.000000
# max                    8.000000                7.000000            296.000000
#
#            duration   radiant_win  tower_status_radiant  tower_status_dire  \
# count  30000.000000  30000.000000           30000.00000       30000.000000
# mean    2398.129500      0.505333            1216.26270        1220.369467
# ...

# %% [raw]
# So, right now we saw all the dataset, and can think about best features/new features and etc.
# We must check:
# 1. loby type. Maybe depending from lobby type algorithm and his param can variate.
# 2. here can be mistake of time. because Valve sometimes change heroes, and their winrate can be increase or decrease depanding from time. p.s. unfortunatly we can't check it< and we will use data in spite of this.
# 3. Does it make sence to use kills/depths/last hits? we can use just features gold and xp.
# 4. Does winrate depanding on first blood/bottle/tp count/items/level(because of xp)?
# 5. What is duration?
#
# So lets find some outlier.

# %%
# Function to calculate missing values by column
def missing_values_table(df):
        # Total missing values
        mis_val = df.isnull().sum()
        
        # Percentage of missing values
        mis_val_percent = 100 * df.isnull().sum() / len(df)
        
        # Make a table with the results
        mis_val_table = pd.concat([mis_val, mis_val_percent], axis=1)
        
        # Rename the columns
        mis_val_table_ren_columns = mis_val_table.rename(
        columns = {0 : 'Missing Values', 1 : '% of Total Values'})
        
        # Sort the table by percentage of missing descending
        mis_val_table_ren_columns = mis_val_table_ren_columns[
            mis_val_table_ren_columns.iloc[:,1] != 0].sort_values(
        '% of Total Values', ascending=False).round(1)
        
        # Print some summary information
        print ("Your selected dataframe has " + str(df.shape[1]) + " columns.\n"      
            "There are " + str(mis_val_table_ren_columns.shape[0]) +
              " columns that have missing values.")
        
        # Return the dataframe with missing information
        return mis_val_table_ren_columns

# %%
missing_values_table(feature)
# Out:
# Your selected dataframe has 109 columns.
# There are 12 columns that have missing values.
#                              Missing Values  % of Total Values
# first_blood_player2                   43987               45.2
# radiant_flying_courier_time           27479               28.3
# dire_flying_courier_time              26098               26.8
# first_blood_time                      19553               20.1
# first_blood_team                      19553               20.1
# first_blood_player1                   19553               20.1
# dire_bottle_time                      16143               16.6
# radiant_bottle_time                   15691               16.1
# radiant_first_ward_time                1836                1.9
# dire_first_ward_time                   1826                1.9
# radiant_courier_time                    692                0.7
# dire_courier_time                       676                0.7

# %% [raw]
# So, we don't have outliers here because of creating dataset by computer.
# But we can exclude some data like match with 0 second play match.
# Let's find out them.

# %%
def plot_hist(Series):
    plt.figure(figsize = (8,8))

    plt.style.use('fivethirtyeight')
    plt.hist(Series, bins=100, edgecolor='k')
    plt.ylabel('Number of matchs')
plot_hist(feature['duration'])

# %%
plot_hist(feature['r1_gold']+feature['r2_gold']+feature['d1_gold']+feature['d2_gold'])

# %%
plot_hist(feature['r1_xp']+feature['r2_xp']+feature['d1_xp']+feature['d2_xp'])

# %%
#lets delete match, where sum of gold = 0
feature = feature[feature['r1_gold']+feature['r2_gold']+feature['r3_gold'] != 0]

# %%
plot_hist(feature['r1_xp']+feature['r2_xp']+feature['d1_xp']+feature['d2_xp'])

# %%
feature['lobby_type'].value_counts()
# Out:
# 1    55830
# 7    28466
# 0    12647
# Name: lobby_type, dtype: int64

# %% [markdown]
# that's really good. Because in lobbies.csv we have some lobbies like Co-op with bots(4) or Solo mid 1vs1(8)

# %% [raw]
# Look's like we clean all outliers.
# Let's investigate some features what can be unusfull and delete them.

# %%
columns_for_delete = ['match_id', 'lobby_type', 'start_time', 'level', 'lh', 'items','duration']
for col in feature.columns:
    for col_del in columns_for_delete:
        if col_del in col:        
            feature = feature.drop(col,axis=1)
feature.head()
# Out:
#    r1_hero  r1_xp  r1_gold  r1_kills  r1_deaths  r2_hero  r2_xp  r2_gold  \
# 0       11   2098     1489         0          0       67    842      991
# 1       42   1188     1033         0          1       49   1596      993
# 2       33   1319     1270         0          0       98   1314      775
# 3       29   1779     1056         0          0       30    539      539
# 4       13   1431     1090         1          0       27    629      552
#
#    r2_kills  r2_deaths  ...  dire_tpscroll_count  dire_boots_count  \
# 0         0          0  ...                    3                 4
# 1         0          1  ...                    5                 4
# 2         0          0  ...                    3                 4
# 3         0          0  ...                    0                 4
# 4         0          1  ...                    6                 3
#
#    dire_ward_observer_count  dire_ward_sentry_count  dire_first_ward_time  \
# ...

# %%
feature.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 96943 entries, 0 to 97229
# Data columns (total 75 columns):
# r1_hero                        96943 non-null int64
# r1_xp                          96943 non-null int64
# r1_gold                        96943 non-null int64
# r1_kills                       96943 non-null int64
# r1_deaths                      96943 non-null int64
# r2_hero                        96943 non-null int64
# r2_xp                          96943 non-null int64
# r2_gold                        96943 non-null int64
# r2_kills                       96943 non-null int64
# r2_deaths                      96943 non-null int64
# r3_hero                        96943 non-null int64
# r3_xp                          96943 non-null int64
# r3_gold                        96943 non-null int64
# r3_kills                       96943 non-null int64
# r3_deaths                      96943 non-null int64
# r4_hero                        96943 non-null int64
# ...

# %%
col_good_feat = ['blood', 'radiant', 'dire']
feature_add = pd.DataFrame()
for col in feature.columns:
    for col_del in col_good_feat:
        if col_del in col:
            feature_add[col] = feature.pop(col)
feature['radiant_win'] = feature_add.pop('radiant_win')

# %%
feature_add.head()
# Out:
#    first_blood_time  first_blood_team  first_blood_player1  \
# 0               7.0               1.0                  9.0
# 1              54.0               1.0                  7.0
# 2             224.0               0.0                  3.0
# 3               NaN               NaN                  NaN
# 4             -21.0               1.0                  6.0
#
#    first_blood_player2  radiant_bottle_time  radiant_courier_time  \
# 0                  NaN                134.0                 -80.0
# 1                  NaN                173.0                 -80.0
# 2                  NaN                 63.0                 -82.0
# 3                  NaN                208.0                 -75.0
# 4                  NaN                166.0                 -81.0
#
#    radiant_flying_courier_time  radiant_tpscroll_count  radiant_boots_count  \
# 0                        244.0                       2                    2
# ...

# %%
feature.head()
# Out:
#    r1_hero  r1_xp  r1_gold  r1_kills  r1_deaths  r2_hero  r2_xp  r2_gold  \
# 0       11   2098     1489         0          0       67    842      991
# 1       42   1188     1033         0          1       49   1596      993
# 2       33   1319     1270         0          0       98   1314      775
# 3       29   1779     1056         0          0       30    539      539
# 4       13   1431     1090         1          0       27    629      552
#
#    r2_kills  r2_deaths  ...  d4_xp  d4_gold  d4_kills  d4_deaths  d5_hero  \
# 0         0          0  ...    742      500         0          0       84
# 1         0          1  ...    440      583         0          0       12
# 2         0          0  ...   1319      667         0          0       80
# 3         0          0  ...    674      537         0          0       20
# 4         0          1  ...   1815     1275         0          0        8
#
#    d5_xp  d5_gold  d5_kills  d5_deaths  radiant_win
# ...

# %%
feature.to_csv('D:/Prog/ML/datasets/data/new_features.csv', index=False)
feature_add.to_csv('D:/Prog/ML/datasets/data/new_features_add.csv', index=False)

# %%
feature = pd.read_csv('D:/Prog/ML/datasets/data/new_features.csv')
feature.head()
# Out:
#    r1_hero  r1_xp  r1_gold  r1_kills  r1_deaths  r2_hero  r2_xp  r2_gold  \
# 0       11   2098     1489         0          0       67    842      991
# 1       42   1188     1033         0          1       49   1596      993
# 2       33   1319     1270         0          0       98   1314      775
# 3       29   1779     1056         0          0       30    539      539
# 4       13   1431     1090         1          0       27    629      552
#
#    r2_kills  r2_deaths  ...  d4_xp  d4_gold  d4_kills  d4_deaths  d5_hero  \
# 0         0          0  ...    742      500         0          0       84
# 1         0          1  ...    440      583         0          0       12
# 2         0          0  ...   1319      667         0          0       80
# 3         0          0  ...    674      537         0          0       20
# 4         0          1  ...   1815     1275         0          0        8
#
#    d5_xp  d5_gold  d5_kills  d5_deaths  radiant_win
# ...

# %%
feature_add = pd.read_csv('D:/Prog/ML/datasets/data/new_features_add.csv')
feature_add.head()
# Out:
#    first_blood_time  first_blood_team  first_blood_player1  \
# 0               7.0               1.0                  9.0
# 1              54.0               1.0                  7.0
# 2             224.0               0.0                  3.0
# 3               NaN               NaN                  NaN
# 4             -21.0               1.0                  6.0
#
#    first_blood_player2  radiant_bottle_time  radiant_courier_time  \
# 0                  NaN                134.0                 -80.0
# 1                  NaN                173.0                 -80.0
# 2                  NaN                 63.0                 -82.0
# 3                  NaN                208.0                 -75.0
# 4                  NaN                166.0                 -81.0
#
#    radiant_flying_courier_time  radiant_tpscroll_count  radiant_boots_count  \
# 0                        244.0                       2                    2
# ...
